# %%
import pandas as pd
import numpy as np

# %%
# File to Load (Remember to Change These)
file_to_load = "Resources/purchase_data.csv"

# Read Purchasing File and store into Pandas data frame
purchase_data = pd.read_csv(file_to_load)

# %%
purchase_data.head()
# Out:
#    Purchase ID             SN  Age Gender  Item ID  \
# 0            0        Lisim78   20   Male      108
# 1            1    Lisovynya38   40   Male      143
# 2            2     Ithergue48   24   Male       92
# 3            3  Chamassasya86   24   Male      100
# 4            4      Iskosia90   23   Male      131
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88
# 3                                Blindscythe   3.27
# 4                                       Fury   1.44

# %%
#Calculating the Number of Unique Players
player_demo = purchase_data.loc[:, ["Gender", "SN", "Age"]]
player_demo = player_demo.drop_duplicates()
num_players = player_demo.count()[0]
pd.DataFrame({"Total Players": [num_players]})
# Out:
#    Total Players
# 0            576

# %%
#Purchasing Information
unique_items = len(purchase_data['Item ID'].unique())
average_price = round(purchase_data['Price'].mean(), 2)
total_purchases = len(purchase_data['Price'])
total_revenue = float(purchase_data['Price'].sum())

summary_dataframe = pd.DataFrame({
    'Number of Unique Items': [unique_items],
    'Average Price': '$' + str(average_price),
    'Total Number of Purchases': [total_purchases],
    'Total Revenue': '$' + str(total_revenue)
})

summary_dataframe
# Out:
#    Number of Unique Items Average Price  Total Number of Purchases  \
# 0                     179         $3.05                        780
#
#   Total Revenue
# 0      $2379.77

# %%
#Gender Demographic
gender_count = player_demo["Gender"].value_counts()
gender_percent = gender_count/num_players*100
gender_count
gender_demographics = pd.DataFrame({
    'Percentage of Players': gender_percent,
    'Total Count': gender_count
})

gender_demographics = gender_demographics.round(2)
gender_demographics.head()
# Out:
#                        Percentage of Players  Total Count
# Male                                   84.03          484
# Female                                 14.06           81
# Other / Non-Disclosed                   1.91           11

# %%
#Purchasing Analysis Gender
purchase_count = purchase_data.groupby(["Gender"]).count()["Price"]
purchase_average_price = purchase_data.groupby(["Gender"]).mean()["Price"]
total_purchase_value = purchase_data.groupby(["Gender"]).sum()["Price"]
average_purchase_gender = total_purchase_value/gender_count

# %%
purchasing_analysis = pd.DataFrame({
    'Purchase Count': purchase_count,
    'Average Purchase Price': purchase_average_price,
    'Total Purchase Value': total_purchase_value,
    'Average Purchase Total by Gender': average_purchase_gender
})

# %%
summary_purchasing_analysis = purchasing_analysis[["Purchase Count", "Average Purchase Price", "Total Purchase Value", "Average Purchase Total by Gender"]]
summary_purchasing_analysis = summary_purchasing_analysis.round(2)
summary_purchasing_analysis.head()
# Out:
#                        Purchase Count  Average Purchase Price  \
# Female                            113                    3.20
# Male                              652                    3.02
# Other / Non-Disclosed              15                    3.35
#
#                        Total Purchase Value  Average Purchase Total by Gender
# Female                               361.94                              4.47
# Male                                1967.64                              4.07
# Other / Non-Disclosed                 50.19                              4.56

# %%
#Age Demographics

bins = [0, 10, 15, 20, 25, 30, 35, 40, 999]
group_names = ["<10", "10-14", "15-19", "20-24", "25-29", "30-34", "35-39", "40+"]

age_groups = player_demo.loc[:, ["SN", "Age"]]
age_groups["Age Ranges"] = pd.cut(age_groups["Age"], bins, labels=group_names, right=False)
age_groups.head()
# Out:
#               SN  Age Age Ranges
# 0        Lisim78   20      20-24
# 1    Lisovynya38   40        40+
# 2     Ithergue48   24      20-24
# 3  Chamassasya86   24      20-24
# 4      Iskosia90   23      20-24

# %%
age_demo_totals = age_groups["Age Ranges"].value_counts()
age_demo_percents = (age_demo_totals/num_players *100).round(2)
age_demographics = pd.DataFrame({
    "Age Group Total": age_demo_totals,
    "Percentage of Total": age_demo_percents
})

age_demographics.sort_index()
# Out:
#        Age Group Total  Percentage of Total
# <10                 17                 2.95
# 10-14               22                 3.82
# 15-19              107                18.58
# 20-24              258                44.79
# 25-29               77                13.37
# 30-34               52                 9.03
# 35-39               31                 5.38
# 40+                 12                 2.08

# %%
#Purchasing Analysis by Age
purchase_data["Total Count"] = pd.cut(purchase_data["Age"], bins, labels=group_names, right=False)
less_purchase_data = purchase_data[['Total Count', 'SN', 'Price']]

less_purchase_grouped = less_purchase_data.groupby('Total Count')
purchase_counts = less_purchase_grouped['Price'].count()
average_prices = round(less_purchase_grouped['Price'].mean(), 2)
total_spent = round(less_purchase_grouped['Price'].sum(), 2)
spending_per_person = round(total_spent/age_demo_totals, 2)

# %%
age_summary = pd.DataFrame({
    "Purchase Count": purchase_counts,
    "Average Purchase Price": average_prices,
    "Total Purchase Value": total_spent,
    "Average Total Purchase per Person": spending_per_person
})
age_summary.head()
# Out:
#        Purchase Count  Average Purchase Price  Total Purchase Value  \
# <10                23                    3.35                 77.13
# 10-14              28                    2.96                 82.78
# 15-19             136                    3.04                412.89
# 20-24             365                    3.05               1114.06
# 25-29             101                    2.90                293.00
#
#        Average Total Purchase per Person
# <10                                 4.54
# 10-14                               3.76
# 15-19                               3.86
# 20-24                               4.32
# 25-29                               3.81

# %%
#Identifying Top Spenders
top_spenders = purchase_data.groupby('SN')
purchase_count = top_spenders['Gender'].count()
average_spending = round(top_spenders['Price'].mean(), 2)
total_purchase = round(top_spenders['Price'].sum(), 2)

# %%
top_spenders_summary = pd.DataFrame({
    "Purchase Count": purchase_count,
    "Average Purchase Price": average_spending,
    "Total Purchase Value": total_purchase
})
top_spenders_summary.sort_values('Total Purchase Value', ascending=False).reset_index().head()
# Out:
#             SN  Purchase Count  Average Purchase Price  Total Purchase Value
# 0    Lisosia93               5                    3.79                 18.96
# 1  Idastidru52               4                    3.86                 15.45
# 2   Chamjask73               3                    4.61                 13.83
# 3       Iral74               4                    3.40                 13.62
# 4  Iskadarya95               3                    4.37                 13.10

# %%
#Most Popular Items
items = purchase_data.groupby(['Item ID', 'Item Name'])
purchase_count_items = items['Gender'].count()
average_spending_items = round(items['Price'].mean(), 2)
total_purchase_items = round(items['Price'].sum(), 2)

# %%
popular_items_summary = pd.DataFrame({
    "Purchase Count": purchase_count_items,
    "Item Price": average_spending_items,
    "Total Purchase Value": total_purchase_items
})
popular_items_summary.sort_values('Purchase Count', ascending=False).head()
# Out:
#                                                       Purchase Count  \
# Item ID Item Name
# 92      Final Critic                                              13
# 178     Oathbreaker, Last Hope of the Breaking Storm              12
# 145     Fiery Glass Crusader                                       9
# 132     Persuasion                                                 9
# 108     Extraction, Quickblade Of Trembling Hands                  9
#
#                                                       Item Price  \
# Item ID Item Name
# 92      Final Critic                                        4.61
# 178     Oathbreaker, Last Hope of the Breaking Storm        4.23
# 145     Fiery Glass Crusader                                4.58
# 132     Persuasion                                          3.22
# 108     Extraction, Quickblade Of Trembling Hands           3.53
#
#                                                       Total Purchase Value
# Item ID Item Name
# ...

# %%
popular_items_summary.sort_values('Total Purchase Value', ascending=False).head()
# Out:
#                                                       Purchase Count  \
# Item ID Item Name
# 92      Final Critic                                              13
# 178     Oathbreaker, Last Hope of the Breaking Storm              12
# 82      Nirvana                                                    9
# 145     Fiery Glass Crusader                                       9
# 103     Singed Scalpel                                             8
#
#                                                       Item Price  \
# Item ID Item Name
# 92      Final Critic                                        4.61
# 178     Oathbreaker, Last Hope of the Breaking Storm        4.23
# 82      Nirvana                                             4.90
# 145     Fiery Glass Crusader                                4.58
# 103     Singed Scalpel                                      4.35
#
#                                                       Total Purchase Value
# Item ID Item Name
# ...
